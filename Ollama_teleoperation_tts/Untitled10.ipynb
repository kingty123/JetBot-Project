# %%
import asyncio
import websockets
import json
import logging
from jetbot import Robot, Camera, bgr8_to_jpeg
import base64

# Logging Setup
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Configuration
WEBSOCKET_PORT = 8766
CAMERA_WIDTH = 300
CAMERA_HEIGHT = 300
FPS = 10

# JetBot Initialization
try:
    robot = Robot()
    camera = Camera.instance(width=CAMERA_WIDTH, height=CAMERA_HEIGHT)
    logger.info("JetBot initialized successfully.")
except Exception as e:
    logger.error(f"JetBot initialization failed: {e}")
    robot = None
    camera = None

# Command Handling
async def handle_command(command):
    if not robot:
        logger.error("Robot not initialized.")
        return
    try:
        speeds = {
            "forward_slow": (0.2, 0.2), "forward_medium": (0.4, 0.4), "forward_fast": (0.6, 0.6),
            "backward_slow": (-0.2, -0.2), "backward_medium": (-0.4, -0.4), "backward_fast": (-0.6, -0.6),
            "left_slow": (-0.1, 0.2), "left_medium": (-0.2, 0.4), "left_fast": (-0.3, 0.6),
            "right_slow": (0.2, -0.1), "right_medium": (0.4, -0.2), "right_fast": (0.6, -0.3),
            "stop": (0.0, 0.0)
        }
        left_speed, right_speed = speeds.get(command, (0.0, 0.0))
        robot.set_motors(left_speed, right_speed)
        logger.info(f"Command: {command}, Motors: Left={left_speed}, Right={right_speed}")
    except Exception as e:
        logger.error(f"Command execution error: {e}")
        robot.stop()

# WebSocket Handler
async def websocket_handler(websocket, path):
    logger.info("WebSocket connection established")
    async def send_image_stream():
        if not camera:
            return
        while True:
            try:
                frame = camera.value
                if frame is not None:
                    image_base64 = base64.b64encode(bgr8_to_jpeg(frame)).decode('utf-8')
                    await websocket.send(json.dumps({"image": image_base64}))
                await asyncio.sleep(1.0 / FPS)
            except Exception as e:
                logger.error(f"Image stream error: {e}")
                break

    image_task = asyncio.ensure_future(send_image_stream())
    try:
        async for message in websocket:
            try:
                data = json.loads(message)
                command = data.get("command", "stop")
                await handle_command(command)
            except json.JSONDecodeError:
                logger.error("Invalid JSON received")
            except Exception as e:
                logger.error(f"Message handling error: {e}")
    except websockets.ConnectionClosed:
        logger.info("WebSocket connection closed by client")
    except Exception as e:
        logger.error(f"WebSocket error: {e}")
    finally:
        image_task.cancel()
        if robot:
            robot.stop()
            logger.info("Motors stopped on disconnect")

# Main Function
async def main():
    while True:
        try:
            server = await websockets.serve(websocket_handler, "0.0.0.0", WEBSOCKET_PORT)
            logger.info(f"WebSocket server running on port {WEBSOCKET_PORT}")
            await asyncio.Future()
        except Exception as e:
            logger.error(f"Server error: {e}")
            await asyncio.sleep(5)
            logger.info("Retrying server start...")

if __name__ == "__main__":
    if robot:
        robot.stop()
    loop = asyncio.get_event_loop()
    try:
        loop.run_until_complete(main())
        loop.run_forever()
    except KeyboardInterrupt:
        logger.info("Shutting down server")
        if robot:
            robot.stop()
    finally:
        loop.close()
# Out:
# 2025-03-26 08:50:17,575 - ERROR - JetBot initialization failed: Could not initialize camera.  Please see error trace.
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-1-8c0e9b31a598> in <module>
#     102     try:
# --> 103         loop.run_until_complete(main())
#     104         loop.run_forever()
#
# /usr/lib/python3.6/asyncio/base_events.py in run_until_complete(self, future)
#     470         try:
# --> 471             self.run_forever()
#     472         except:
#
# /usr/lib/python3.6/asyncio/base_events.py in run_forever(self)
#     424         if self.is_running():
# --> 425             raise RuntimeError('This event loop is already running')
#     426         if events._get_running_loop() is not None:
#
# RuntimeError: This event loop is already running
#
# During handling of the above exception, another exception occurred:
#
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-1-8c0e9b31a598> in <module>
#     108             robot.stop()
#     109     finally:
# --> 110         loop.close()
#
# /usr/lib/python3.6/asyncio/unix_events.py in close(self)
#      61
#      62     def close(self):
# ---> 63         super().close()
#      64         if not sys.is_finalizing():
#      65             for sig in list(self._signal_handlers):
#
# /usr/lib/python3.6/asyncio/selector_events.py in close(self)
#      94     def close(self):
#      95         if self.is_running():
# ---> 96             raise RuntimeError("Cannot close a running event loop")
#      97         if self.is_closed():
#      98             return
#
# RuntimeError: Cannot close a running event loop
# 2025-03-26 08:50:17,987 - INFO - WebSocket server running on port 8766
# 2025-03-26 08:50:25,143 - INFO - WebSocket connection established
# 2025-03-26 08:50:51,568 - INFO - WebSocket connection established

# %%
import asyncio
import websockets
import json
import logging
from jetbot import Robot, Camera, bgr8_to_jpeg
import base64

# Logging Setup
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Configuration
WEBSOCKET_PORT = 8766
CAMERA_WIDTH = 300
CAMERA_HEIGHT = 300
FPS = 10

# JetBot Initialization
try:
    robot = Robot()
    camera = Camera.instance(width=CAMERA_WIDTH, height=CAMERA_HEIGHT)
    logger.info("JetBot initialized successfully.")
except Exception as e:
    logger.error(f"JetBot initialization failed: {e}")
    robot = None
    camera = None

# Command Handling
async def handle_command(command):
    if not robot:
        logger.error("Robot not initialized.")
        return
    try:
        speeds = {
            "forward_slow": (0.2, 0.2), "forward_medium": (0.4, 0.4), "forward_fast": (0.6, 0.6),
            "backward_slow": (-0.2, -0.2), "backward_medium": (-0.4, -0.4), "backward_fast": (-0.6, -0.6),
            "left_slow": (-0.1, 0.2), "left_medium": (-0.2, 0.4), "left_fast": (-0.3, 0.6),
            "right_slow": (0.2, -0.1), "right_medium": (0.4, -0.2), "right_fast": (0.6, -0.3),
            "stop": (0.0, 0.0)
        }
        left_speed, right_speed = speeds.get(command, (0.0, 0.0))
        robot.set_motors(left_speed, right_speed)
        logger.info(f"Command: {command}, Motors: Left={left_speed}, Right={right_speed}")
    except Exception as e:
        logger.error(f"Command execution error: {e}")
        robot.stop()

# WebSocket Handler
async def websocket_handler(websocket, path):
    logger.info("WebSocket connection established")
    async def send_image_stream():
        if not camera:
            return
        while True:
            try:
                frame = camera.value
                if frame is not None:
                    image_base64 = base64.b64encode(bgr8_to_jpeg(frame)).decode('utf-8')
                    await websocket.send(json.dumps({"image": image_base64}))
                await asyncio.sleep(1.0 / FPS)
            except Exception as e:
                logger.error(f"Image stream error: {e}")
                break

    image_task = asyncio.ensure_future(send_image_stream())
    try:
        async for message in websocket:
            try:
                data = json.loads(message)
                command = data.get("command", "stop")
                await handle_command(command)
            except json.JSONDecodeError:
                logger.error("Invalid JSON received")
            except Exception as e:
                logger.error(f"Message handling error: {e}")
    except websockets.ConnectionClosed:
        logger.info("WebSocket connection closed by client")
    except Exception as e:
        logger.error(f"WebSocket error: {e}")
    finally:
        image_task.cancel()
        if robot:
            robot.stop()
            logger.info("Motors stopped on disconnect")

# Main Function
async def main():
    while True:
        try:
            server = await websockets.serve(websocket_handler, "0.0.0.0", WEBSOCKET_PORT)
            logger.info(f"WebSocket server running on port {WEBSOCKET_PORT}")
            await asyncio.Future()
        except Exception as e:
            logger.error(f"Server error: {e}")
            await asyncio.sleep(5)
            logger.info("Retrying server start...")

if __name__ == "__main__":
    if robot:
        robot.stop()
    loop = asyncio.get_event_loop()
    try:
        loop.run_until_complete(main())
        loop.run_forever()
    except KeyboardInterrupt:
        logger.info("Shutting down server")
        if robot:
            robot.stop()
    finally:
        loop.close()
# Out:
# 2025-03-26 07:50:17,015 - INFO - WebSocket server running on port 8766
# 2025-03-26 07:51:16,057 - INFO - WebSocket connection established
# 2025-03-26 07:52:13,195 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:16,296 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:18,828 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:21,393 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:23,948 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:26,505 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:29,019 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:31,583 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:34,164 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:36,695 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:39,246 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:41,792 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:44,340 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:46,886 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:49,404 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:51,899 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:54,436 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:56,997 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:52:59,512 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:02,027 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:04,569 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:07,182 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:09,772 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:12,364 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:14,931 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:17,501 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:20,074 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:22,627 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:25,196 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:27,719 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:30,260 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:32,778 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:35,351 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:37,895 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:40,421 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:42,960 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:45,471 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:47,997 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:50,542 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:53,118 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:55,673 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:53:58,204 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:54:00,738 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:54:03,299 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:54:05,854 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:54:08,418 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:54:10,995 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:54:13,580 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:54:16,125 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:54:18,696 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:54:21,257 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:54:23,826 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 07:54:24,211 - INFO - Command: stop, Motors: Left=0.0, Right=0.0
# 2025-03-26 08:04:45,101 - INFO - Motors stopped on disconnect
# 2025-03-26 08:04:45,103 - ERROR - Image stream error:
# 2025-03-26 08:05:11,634 - INFO - WebSocket connection established
# 2025-03-26 08:05:36,306 - INFO - Motors stopped on disconnect
# 2025-03-26 08:05:36,310 - ERROR - Image stream error:
# 2025-03-26 08:06:03,552 - INFO - WebSocket connection established
# 2025-03-26 08:06:21,751 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:06:24,763 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:06:27,285 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:06:29,843 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:06:32,385 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:06:34,942 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:06:37,521 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:06:40,046 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:06:42,589 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:06:45,099 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:06:47,639 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:06:50,191 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:06:52,751 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:06:55,317 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:06:57,874 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:07:00,426 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:07:02,974 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:07:05,507 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:07:08,101 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:07:10,666 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:07:13,223 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:07:13,613 - INFO - Command: stop, Motors: Left=0.0, Right=0.0
# 2025-03-26 08:07:41,797 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:07:44,774 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:07:47,351 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:07:49,913 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:07:52,446 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:07:53,495 - INFO - Command: stop, Motors: Left=0.0, Right=0.0
# 2025-03-26 08:08:27,957 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:08:29,814 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:08:31,848 - INFO - Command: forward_medium, Motors: Left=0.4, Right=0.4
# 2025-03-26 08:08:33,864 - INFO - Command: stop, Motors: Left=0.0, Right=0.0
# 2025-03-26 08:08:44,318 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:08:47,396 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:08:49,948 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:08:52,610 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:08:53,240 - INFO - Command: stop, Motors: Left=0.0, Right=0.0
# 2025-03-26 08:09:37,613 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:09:40,625 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:09:43,210 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:09:45,858 - INFO - Command: forward_slow, Motors: Left=0.2, Right=0.2
# 2025-03-26 08:09:46,986 - INFO - Command: stop, Motors: Left=0.0, Right=0.0
# 2025-03-26 08:11:59,530 - INFO - Motors stopped on disconnect
# 2025-03-26 08:11:59,532 - ERROR - Image stream error:
# 2025-03-26 08:12:11,995 - INFO - WebSocket connection established
# 2025-03-26 08:12:12,190 - INFO - Motors stopped on disconnect
# 2025-03-26 08:12:12,193 - ERROR - Image stream error:
